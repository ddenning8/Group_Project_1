# %%
# %matplotlib notebook

# %%
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import datetime as dt

# %%
housing_df = pd.read_csv("Resources/DC_Properties.csv")
# Out:
# C:\Users\freguenet3\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (18,19,20,21,22,23,24,33,34,35,37,43,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
housing_df.head()
# Out:
#    Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 0           0       4          0      Warm Cool  Y        2.0      8      4
# 1           1       3          1      Warm Cool  Y        2.0     11      5
# 2           2       3          1  Hot Water Rad  Y        2.0      9      5
# 3           3       3          1  Hot Water Rad  Y        2.0      8      5
# 4           4       2          1      Warm Cool  Y        1.0     11      3
#
#       AYB  YR_RMDL   ...     LONGITUDE  ASSESSMENT_NBHD ASSESSMENT_SUBNBHD  \
# 0  1910.0   1988.0   ...    -77.040832       Old City 2   040 D Old City 2
# 1  1898.0   2007.0   ...    -77.040764       Old City 2   040 D Old City 2
# 2  1910.0   2009.0   ...    -77.040678       Old City 2   040 D Old City 2
# 3  1900.0   2003.0   ...    -77.040629       Old City 2   040 D Old City 2
# 4  1913.0   2012.0   ...    -77.039361       Old City 2   040 D Old City 2
#
# ...

# %%
housing_df.columns
# Out:
# Index(['Unnamed: 0', 'BATHRM', 'HF_BATHRM', 'HEAT', 'AC', 'NUM_UNITS', 'ROOMS',
#        'BEDRM', 'AYB', 'YR_RMDL', 'EYB', 'STORIES', 'SALEDATE', 'PRICE',
#        'QUALIFIED', 'SALE_NUM', 'GBA', 'BLDG_NUM', 'STYLE', 'STRUCT', 'GRADE',
#        'CNDTN', 'EXTWALL', 'ROOF', 'INTWALL', 'KITCHENS', 'FIREPLACES',
#        'USECODE', 'LANDAREA', 'GIS_LAST_MOD_DTTM', 'SOURCE', 'CMPLX_NUM',
#        'LIVING_GBA', 'FULLADDRESS', 'CITY', 'STATE', 'ZIPCODE', 'NATIONALGRID',
#        'LATITUDE', 'LONGITUDE', 'ASSESSMENT_NBHD', 'ASSESSMENT_SUBNBHD',
#        'CENSUS_TRACT', 'CENSUS_BLOCK', 'WARD', 'SQUARE', 'X', 'Y', 'QUADRANT'],
#       dtype='object')

# %%
housing_df.dtypes.head
# Out:
# <bound method NDFrame.head of Unnamed: 0              int64
# BATHRM                  int64
# HF_BATHRM               int64
# HEAT                   object
# AC                     object
# NUM_UNITS             float64
# ROOMS                   int64
# BEDRM                   int64
# AYB                   float64
# YR_RMDL               float64
# EYB                     int64
# STORIES               float64
# SALEDATE               object
# PRICE                 float64
# QUALIFIED              object
# SALE_NUM                int64
# GBA                   float64
# BLDG_NUM                int64
# STYLE                  object
# STRUCT                 object
# GRADE                  object
# CNDTN                  object
# EXTWALL                object
# ROOF                   object
# INTWALL                object
# KITCHENS              float64
# FIREPLACES              int64
# USECODE                 int64
# LANDAREA                int64
# GIS_LAST_MOD_DTTM      object
# ...

# %%
housing_df.count()
# Out:
# Unnamed: 0            158957
# BATHRM                158957
# HF_BATHRM             158957
# HEAT                  158957
# AC                    158957
# NUM_UNITS             106696
# ROOMS                 158957
# BEDRM                 158957
# AYB                   158686
# YR_RMDL                80928
# EYB                   158957
# STORIES               106652
# SALEDATE              132187
# PRICE                  98216
# QUALIFIED             158957
# SALE_NUM              158957
# GBA                   106696
# BLDG_NUM              158957
# STYLE                 106696
# STRUCT                106696
# GRADE                 106696
# CNDTN                 106696
# EXTWALL               106696
# ROOF                  106696
# INTWALL               106696
# KITCHENS              106695
# FIREPLACES            158957
# USECODE               158957
# LANDAREA              158957
# GIS_LAST_MOD_DTTM     158957
# SOURCE                158957
# CMPLX_NUM              52261
# ...

# %%
housing_df2 = housing_df.drop(["Unnamed: 0", "BLDG_NUM", "NATIONALGRID", "X", "Y"], axis=1)
housing_df2
# Out:
#         BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM     AYB  \
# 0            4          0      Warm Cool  Y        2.0      8      4  1910.0
# 1            3          1      Warm Cool  Y        2.0     11      5  1898.0
# 2            3          1  Hot Water Rad  Y        2.0      9      5  1910.0
# 3            3          1  Hot Water Rad  Y        2.0      8      5  1900.0
# 4            2          1      Warm Cool  Y        1.0     11      3  1913.0
# 5            3          2  Hot Water Rad  Y        1.0     10      5  1913.0
# 6            1          0      Warm Cool  Y        2.0      5      2  1917.0
# 7            3          1  Hot Water Rad  Y        2.0      8      4  1906.0
# 8            3          1      Warm Cool  Y        2.0      7      3  1908.0
# 9            1          1  Hot Water Rad  Y        1.0      6      2  1908.0
# 10           3          0     Forced Air  N        3.0     12      5  1890.0
# ...

# %%
housing_df2 = housing_df2[housing_df2.PRICE.notnull()]
housing_df2['PRICE'].count()
# Out:
# 98216

# %%
housing_df2 = housing_df2[housing_df2.PRICE.notnull()]
residential_df = housing_df2.loc[housing_df2["SOURCE"] == "Residential"]
residential_df['YEAR'] = pd.DatetimeIndex(residential_df['SALEDATE']).year
residential_df['MONTH'] = pd.DatetimeIndex(residential_df['SALEDATE']).month
residential_df2 = residential_df.query("YEAR>1991.0") 
residential_df3 = residential_df2.query("YEAR<2018")
residential_df3['PRICE'].count()
# Out:
# C:\Users\freguenet3\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\freguenet3\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# 54752

# %%
# residential_df3['YEAR'] = pd.DatetimeIndex(residential_df3['SALEDATE']).year
# residential_df3['MONTH'] = pd.DatetimeIndex(residential_df3['SALEDATE']).month
# residential_df3.head(5)
# Out:
# C:\Users\freguenet3\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\freguenet3\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#    BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM     AYB  \
# 0       4          0      Warm Cool  Y        2.0      8      4  1910.0
# 2       3          1  Hot Water Rad  Y        2.0      9      5  1910.0
# ...

# %%
NE = residential_df3[["YEAR", "PRICE", "QUADRANT"]]
price_evolution_by_year
# Out:
#         YEAR      PRICE QUADRANT
# 0       2003  1095000.0       NW
# 2       2016  2100000.0       NW
# 3       2006  1602000.0       NW
# 5       2010  1950000.0       NW
# 7       2011  1050000.0       NW
# 14      2011  1325000.0       NW
# 16      2010  1240000.0       NW
# 19      2001   592250.0       NW
# 20      2016    33232.0       NW
# 22      2006   907400.0       NW
# 23      2012  1065000.0       NW
# 24      2012  1100000.0       NW
# 25      1996    20000.0       NW
# 27      2005   703700.0       NW
# 29      2013  1210000.0       NW
# 32      1999   130500.0       NW
# 37      1997   339500.0       NW
# 40      2006  1050000.0       NW
# 41      2016  1550000.0       NW
# 42      2015  1599900.0       NW
# 44      2017  1700000.0       NW
# 45      2001   450000.0       NW
# 46      2011   846000.0       NW
# 48      1999   348500.0       NW
# 50      2009   849000.0       NW
# 52      2006  1312000.0       NW
# 54      1997   390000.0       NW
# ...

# %%
NW1 = residential_df3.loc[residential_df3["QUADRANT"] == "NW" , ['QUADRANT','PRICE','YEAR']]
NW2 = NW1.groupby('YEAR')['PRICE'].mean().round(0)
NW2
                          
# ave_price_evolution_since92_NW = price_evolution_since92_NW.groupby("YEAR")["PRICE"].mean().round(0)
# ave_price_evolution_since92_NW_df = pd.DataFrame(ave_price_evolution_since92_NW)
# # ave_price_evolution_since92_NW_df.plot()
# ave_price_evolution_since92_NW_df
# Out:
# YEAR
# 1992.0     320172.0
# 1993.0     284623.0
# 1994.0     284057.0
# 1995.0     292569.0
# 1996.0     300853.0
# 1997.0     321744.0
# 1998.0     302078.0
# 1999.0     334111.0
# 2000.0     374810.0
# 2001.0     424761.0
# 2002.0     490592.0
# 2003.0     580597.0
# 2004.0     661435.0
# 2005.0     785447.0
# 2006.0     820582.0
# 2007.0     885203.0
# 2008.0     819722.0
# 2009.0     769656.0
# 2010.0     835955.0
# 2011.0     856319.0
# 2012.0     873919.0
# 2013.0     978846.0
# 2014.0     998252.0
# 2015.0    1033005.0
# 2016.0    1058664.0
# 2017.0    1112038.0
# Name: PRICE, dtype: float64

# %%
price_evolution_by_year = pd.DataFrame(residential_df3[["YEAR", "PRICE", "QUADRANT"]])


# clean_price_evolution_since92 = price_evolution_since92.dropna(axis=1, how='any')
# price_evolution_since92_df = pd.DataFrame(clean_price_evolution_since92)
price_evolution_since92_NW = price_evolution_since92.loc[price_evolution_since92["QUADRANT"] == "NW"]
ave_price_evolution_since92_NW = price_evolution_since92_NW.groupby("YEAR")["PRICE"].mean().round(0)
ave_price_evolution_since92_NW_df = pd.DataFrame(ave_price_evolution_since92_NW)
ave_price_evolution_since92_NW_df.plot()

price_evolution_since92_NE = price_evolution_since92.loc[price_evolution_since92["QUADRANT"] == "NE"]
ave_price_evolution_since92_NE = price_evolution_since92_NW.groupby("YEAR")["PRICE"].mean()
ave_price_evolution_since92_NE_df = pd.DataFrame(ave_price_evolution_since92_NE)
ave_price_evolution_since92_NE_df.plot()

price_evolution_since92_SW = price_evolution_since92.loc[price_evolution_since92["QUADRANT"] == "SW"]
ave_price_evolution_since92_SW = price_evolution_since92_NW.groupby("YEAR")["PRICE"].mean()
ave_price_evolution_since92_SW_df = pd.DataFrame(ave_price_evolution_since92_SW)
ave_price_evolution_since92_SW_df.plot()

price_evolution_since92_SE = price_evolution_since92.loc[price_evolution_since92["QUADRANT"] == "SE"]
ave_price_evolution_since92_SE = price_evolution_since92_NW.groupby("YEAR")["PRICE"].mean()
ave_price_evolution_since92_SE_df = pd.DataFrame(ave_price_evolution_since92_SE)
ave_price_evolution_since92_SE_df.plot()

# ax = df1.plot()
# df2.plot(ax=ax)




# grouped_since2000 = price_evolution_since2000.groupby(["QUADRANT", "YEAR"])["PRICE"].mean()
# grouped_since2000_df = pd.DataFrame(grouped_since2000)
# grouped_since2000_df.plot()
# clean_price_evolution_since92.plot(x="YEAR", y= "PRICE")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-cba1f4ae5288> in <module>
#       4 # clean_price_evolution_since92 = price_evolution_since92.dropna(axis=1, how='any')
#       5 # price_evolution_since92_df = pd.DataFrame(clean_price_evolution_since92)
# ----> 6 price_evolution_since92_NW = price_evolution_since92.loc[price_evolution_since92["QUADRANT"] == "NW"]
#       7 ave_price_evolution_since92_NW = price_evolution_since92_NW.groupby("YEAR")["PRICE"].mean().round(0)
#       8 ave_price_evolution_since92_NW_df = pd.DataFrame(ave_price_evolution_since92_NW)
#
# NameError: name 'price_evolution_since92' is not defined

# %%
price_evolution_by_year
# Out:
#           YEAR      PRICE QUADRANT
# 0       2003.0  1095000.0       NW
# 2       2016.0  2100000.0       NW
# 3       2006.0  1602000.0       NW
# 5       2010.0  1950000.0       NW
# 7       2011.0  1050000.0       NW
# 8       2018.0  1430000.0       NW
# 14      2011.0  1325000.0       NW
# 16      2010.0  1240000.0       NW
# 19      2001.0   592250.0       NW
# 20      2016.0    33232.0       NW
# 22      2006.0   907400.0       NW
# 23      2012.0  1065000.0       NW
# 24      2012.0  1100000.0       NW
# 25      1996.0    20000.0       NW
# 27      2005.0   703700.0       NW
# 29      2013.0  1210000.0       NW
# 32      1999.0   130500.0       NW
# 37      1997.0   339500.0       NW
# 40      2006.0  1050000.0       NW
# 41      2016.0  1550000.0       NW
# 42      2015.0  1599900.0       NW
# 43      2018.0  1700000.0       NW
# 44      2017.0  1700000.0       NW
# 45      2001.0   450000.0       NW
# 46      2011.0   846000.0       NW
# 48      1999.0   348500.0       NW
# ...
